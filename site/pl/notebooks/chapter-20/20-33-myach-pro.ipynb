# %% [markdown]
# # 20-33 · Projekt końcowy: Ball Pro
#
# Praktyka do sekcji [„Projekt końcowy - Ball Pro” `projects/pygame/bouncing-ball/bouncing_ball.py`.

# %% [markdown]
# ## Cel
#
# Uruchom finalną wersję BouncingBallGame i sprawdź jej kluczowe gwarancje: ruch przez delta time, pauzę i wynik.

# %%
import random
import sys

sys.path.insert(0, "../../projects/pygame/bouncing-ball")
import bouncing_ball as bb

# Początkowy kierunek piłki wybierany jest losowym kątem, dlatego ustalamy seed
# (Rozdział 5): w przeciwnym razie poniższe liczby zmieniałyby się za każdym razem, gdy uruchamiasz laptopa.
random.seed(20)

game = bb.BouncingBallGame()
for _ in range(180):
    game.update(1 / 60)
    game.render()

print("Отскоков:", game.otskokov)
print("Счёт:", game.schet)
print("Состояние:", game.state)
# Out:
# pygame-ce 2.5.8 (SDL 2.32.10, Python 3.14.6)
# Отскоков: 2
# Счёт: 20
# Состояние: SostoyanieIgry.IGRA

# %% [markdown]
# ## Sprawdzenie wyniku

# %%
assert game.otskokov > 0
assert game.schet == game.otskokov * bb.OCHKOV_ZA_OTSKOK
assert bb.RADIUS <= game.x <= bb.SHIRINA - bb.RADIUS
assert bb.RADIUS <= game.y <= bb.VYSOTA - bb.RADIUS
print("Верно: счёт растёт строго вместе с числом отскоков, мяч не покидает поле.")
# Out:
# Верно: счёт растёт строго вместе с числом отскоков, мяч не покидает поле.

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Zatrzymaj grę, ubiegnij kolejne 60 klatek i upewnij się, że ani wynik, ani pozycja piłki nie zmieniły się ani o piksel.

# %%
game.toggle_pause()
do = (game.x, game.y, game.schet, game.otskokov)
for _ in range(60):
    game.update(1 / 60)
posle = (game.x, game.y, game.schet, game.otskokov)

assert do == posle
print("Верно: пауза останавливает игру полностью, а не только отрисовку.")
# Out:
# Верно: пауза останавливает игру полностью, а не только отрисовку.
