# %% [markdown]
# # 04-17 · Fraction i dokładne ułamki
#
# Praktyka do sekcji [„Fraction są ułamkami dokładnymi”

# %% [markdown]
# ## Cel
#
# Opanować dokładną arytmetykę wymierną.

# %% [markdown]
# ## Sprawa robocza

# %%
from fractions import Fraction
print(Fraction(1, 3))
# Out:
# 1/3

# %% [markdown]
# ## Eksperyment 1
#
# Dodaj dokładnie te dwa ułamki.

# %%
from fractions import Fraction
print(Fraction(1, 3) + Fraction(1, 6))
# Out:
# 1/2

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Stwórz Fraction(„0.1”

# %%
from fractions import Fraction
print(Fraction("0.1"))
print(Fraction(0.1))
# Out:
# 1/10
# 3602879701896397/36028797018963968
