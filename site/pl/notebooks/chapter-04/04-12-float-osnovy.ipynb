# %% [markdown]
# # 04-12 · float - Nagrywanie i pierwsze obliczenia
#
# Praktyka do sekcji [„float są liczbami ułamkowymi”

# %% [markdown]
# ## Cel
#
# Opanuj standardowy i naukowy zapis float.

# %% [markdown]
# ## Sprawa robocza

# %%
pi = 3.14
print(type(pi))
# Out:
# <class 'float'>

# %% [markdown]
# ## Eksperyment 1
#
# Notacja naukowa: 1e6 — ile to jest?

# %%
print(1e6)
print(2.5e-3)
# Out:
# 1000000.0
# 0.0025

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Sprawdź, że 10 / 2 to float, a nie int.

# %%
result = 10 / 2
print(result)
print(type(result))
# Out:
# 5.0
# <class 'float'>
