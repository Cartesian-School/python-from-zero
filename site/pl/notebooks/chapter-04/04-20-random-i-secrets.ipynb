# %% [markdown]
# # 04-20 · random vs secrets
#
# Praktyka do sekcji [„random i secrets”](/pl/chapters/rozdzial-04/04-20-random-i-secrets.html).

# %% [markdown]
# ## Cel
#
# Opanować random do gier i zrozumieć, kiedy potrzebny jest secrets.

# %% [markdown]
# ## Sprawa robocza

# %%
import random
random.seed(42)
print(random.randint(1, 6))
# Out:
# 6

# %% [markdown]
# ## Eksperyment 1
#
# Wybierz losowy element z listy.

# %%
import random
random.seed(1)
print(random.choice(["орёл", "решка"]))
# Out:
# орёл

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Stwórz bezpieczny token przez secrets.token_hex().

# %%
import secrets
token = secrets.token_hex(8)
print(len(token))
# Out:
# 16
