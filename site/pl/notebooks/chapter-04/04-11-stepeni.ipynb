# %% [markdown]
# # 04-11 · Stopnie, pow() i abs()
#
# Praktyka do sekcji [„Stopnie i abs()”

# %% [markdown]
# ## Cel
#
# Opanowanie elewacji do mocy i modułu liczby.

# %% [markdown]
# ## Sprawa robocza

# %%
print(2 ** 10)
print(pow(2, 10))
# Out:
# 1024
# 1024

# %% [markdown]
# ## Eksperyment 1

# %%
print(abs(-7))
print(abs(7))
# Out:
# 7
# 7

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Policz pole kwadratu o boku 9, używając **.

# %%
side = 9
area = side ** 2
print(area)
# Out:
# 81
