# %% [markdown]
# # 17-21 · Adaptacyjne boisko
#
# Praktyka do sekcji [„Adaptive Playing Field”

# %% [markdown]
# ## Cel
#
# Zbudować pole 3×3 przez grid() z sticky i weight, aby dopasowało się do rozmiaru okna.

# %% [markdown]
# ## Pro mainloop() w tym laptopie
#
# Zamiast `root.mainloop()` używany tutaj `root.update()` + `root.destroy()` jest takie, że aplikacja jest zbudowana dokładnie tak samo, tylko bez niekończącego się oczekiwania na końcu (zobacz wyjaśnienie w rozdziale 16).

# %% [markdown]
# ## Sprawa robocza

# %%
import tkinter as tk
from tkinter import ttk

root = tk.Tk()
board_frame = ttk.Frame(root)
board_frame.pack(fill="both", expand=True)

for i in range(3):
    board_frame.rowconfigure(i, weight=1)
    board_frame.columnconfigure(i, weight=1)

buttons = []
for index in range(9):
    btn = tk.Button(board_frame, text="", width=3, height=1)
    btn.grid(row=index // 3, column=index % 3, sticky="nsew", padx=3, pady=3)
    buttons.append(btn)

root.update()
print("Клеток создано:", len(buttons))
print("weight столбца 0:", board_frame.grid_columnconfigure(0)["weight"])
root.destroy()
# Out:
# Клеток создано: 9
# weight столбца 0: 1

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Sprawdź to `sticky="nsew"` ustawiony we wszystkich dziewięciu komórkach przez `btn.grid_info()["sticky"]`.

# %%
root = tk.Tk()
board_frame = ttk.Frame(root)
board_frame.pack(fill="both", expand=True)
for i in range(3):
    board_frame.rowconfigure(i, weight=1)
    board_frame.columnconfigure(i, weight=1)

kletki = []
for index in range(9):
    btn = tk.Button(board_frame, text="", width=3, height=1)
    btn.grid(row=index // 3, column=index % 3, sticky="nsew", padx=3, pady=3)
    kletki.append(btn)
root.update()

sticky_vsekh = [str(btn.grid_info()["sticky"]) for btn in kletki]
print("sticky первых трёх клеток:", sticky_vsekh[:3])
assert all(set(s) == set("nsew") for s in sticky_vsekh), \
    "у каждой из девяти клеток должен быть sticky='nsew'"
print("Все девять клеток растягиваются во все четыре стороны своей ячейки.")
root.destroy()
# Out:
# sticky первых трёх клеток: ['nesw', 'nesw', 'nesw']
# Все девять клеток растягиваются во все четыре стороны своей ячейки.
