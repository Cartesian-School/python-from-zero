# %% [markdown]
# # 17-03 · Zmienne i przyciski
#
# Praktyka do sekcji [„Tworzymy zmienne globalne i przyciski”](/pl/chapters/rozdzial-17/17-03-peremennye-knopki.html).

# %% [markdown]
# ## Cel
#
# Utworzenie zmiennych stanu oraz pola z dziewięcioma przyciskami.

# %% [markdown]
# ## Pro mainloop() w tym laptopie
#
# Zamiast `root.mainloop()` używany tutaj `root.update()` + `root.destroy()` jest takie, że aplikacja jest zbudowana dokładnie tak samo, tylko bez niekończącego się oczekiwania na końcu (zobacz wyjaśnienie w rozdziale 16).

# %% [markdown]
# ## Sprawa robocza

# %%
import tkinter as tk

root = tk.Tk()

tekuschij_igrok = "X"
polya = []
igra_okonchena = False

pole_frame = tk.Frame(root)
pole_frame.pack()

for indeks in range(9):
    knopka = tk.Button(pole_frame, text="", font=("Arial", 24, "bold"), width=3, height=1)
    knopka.grid(row=indeks // 3, column=indeks % 3)
    polya.append(knopka)

print("Создано кнопок:", len(polya))
print("Позиция кнопки 4 (центр):", polya[4].grid_info()["row"], polya[4].grid_info()["column"])
root.update()
root.destroy()
# Out:
# Создано кнопок: 9
# Позиция кнопки 4 (центр): 1 1

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Sprawdź, czy indeks // 3 i indeks% 3 dają poprawne współrzędne dla wszystkich dziewięciu kwadratów.

# %%
for indeks in range(9):
    print(indeks, "-> row", indeks // 3, "col", indeks % 3)
# Out:
# 0 -> row 0 col 0
# 1 -> row 0 col 1
# 2 -> row 0 col 2
# 3 -> row 1 col 0
# 4 -> row 1 col 1
# 5 -> row 1 col 2
# 6 -> row 2 col 0
# 7 -> row 2 col 1
# 8 -> row 2 col 2
