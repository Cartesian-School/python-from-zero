# %% [markdown]
# # 18-29 · Architektura PaintApp
#
# Praktyka do sekcji [„Architektura PaintApp”

# %% [markdown]
# ## Cel
#
# Złóż graf obiektowy PaintApp: root, state, document canvas w tej samej klasie.

# %% [markdown]
# ## Pro mainloop() w tym laptopie
#
# Zamiast `root.mainloop()` używany tutaj `root.update()` + `root.destroy()` jest takie, że aplikacja jest zbudowana dokładnie tak samo, tylko bez niekończącego się oczekiwania na końcu (zobacz wyjaśnienie w rozdziale 16).

# %% [markdown]
# ## Sprawa robocza

# %%
import sys
sys.path.insert(0, "../../projects/tkinter/paint-app")

import tkinter as tk
import paint_app as p

root = tk.Tk()
app = p.PaintApp(root)
root.update()

print(type(app.root), type(app.state), type(app.document), type(app.canvas))
root.destroy()
# Out:
# <class 'tkinter.Tk'> <class 'paint_app.DrawingState'> <class 'list'> <class 'tkinter.Canvas'>

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Sprawdź to `app.state.tool` zmienia się po rozmowie telefonicznej `app.set_tool(p.Tool.RECTANGLE)`, a to odzwierciedla się również w `relief` odpowiadający mu przycisk paska narzędzi.
