# %% [markdown]
# # 18-21 · System kolorów
#
# Praktyka do sekcji [„System Kolorów”

# %% [markdown]
# ## Cel
#
# Wybór kolorów i uczciwa kontrola anulowania colorchooser.

# %% [markdown]
# ## Pro mainloop() w tym laptopie
#
# Zamiast `root.mainloop()` używany tutaj `root.update()` + `root.destroy()` jest takie, że aplikacja jest zbudowana dokładnie tak samo, tylko bez niekończącego się oczekiwania na końcu (zobacz wyjaśnienie w rozdziale 16).

# %% [markdown]
# ## Sprawa robocza

# %%
import tkinter as tk

PALETTE = [("Чёрный", "#111827"), ("Красный", "#dc2626"), ("Синий", "#2563eb")]

root = tk.Tk()
current_color = tk.StringVar(value=PALETTE[0][1])

def set_color(hex_color):
    current_color.set(hex_color)

toolbar = tk.Frame(root)
toolbar.pack()
for name, hex_color in PALETTE:
    tk.Button(toolbar, bg=hex_color, width=2, command=lambda c=hex_color: set_color(c)).pack(side="left")

root.update()
print("Текущий цвет:", current_color.get())
root.destroy()
# Out:
# Текущий цвет: #111827

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Napisz funkcję `choose_custom_color()`to powoduje `tkinter.colorchooser.askcolor()`i wyraźnie sprawdź `hex_color is not None` przed wywołaniem `set_color(hex_color)` — co się stanie, jeśli usuniesz ten check-up i klikniesz „Anuluj”
