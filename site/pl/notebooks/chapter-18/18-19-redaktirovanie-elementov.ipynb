# %% [markdown]
# # 18-19 · itemconfig, move, delete
#
# Praktyka do sekcji [„itemconfig, move, delete”](/pl/chapters/rozdzial-18/18-19-redaktirovanie-elementov.html).

# %% [markdown]
# ## Cel
#
# Zmień już istniejący element Canvas: coords, itemconfig, move, delete.

# %% [markdown]
# ## Pro mainloop() w tym laptopie
#
# Zamiast `root.mainloop()` używany tutaj `root.update()` + `root.destroy()` jest takie, że aplikacja jest zbudowana dokładnie tak samo, tylko bez niekończącego się oczekiwania na końcu (zobacz wyjaśnienie w rozdziale 16).

# %% [markdown]
# ## Sprawa robocza

# %%
import tkinter as tk

root = tk.Tk()
canvas = tk.Canvas(root, width=300, height=200, bg="white")
canvas.pack()

item_id = canvas.create_rectangle(10, 10, 80, 60, outline="black", width=2)
root.update()

canvas.itemconfig(item_id, outline="blue", width=4)
canvas.move(item_id, 30, 0)
root.update()
print("Текущие координаты:", canvas.coords(item_id))
root.destroy()
# Out:
# Текущие координаты: [40.0, 10.0, 110.0, 60.0]

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Call `canvas.move(item_id, 30, 0)` DWA razy z rzędu i drukuj `canvas.coords(item_id)` - Upewnij się, że element przesunął się łącznie o 60 pikseli, zamiast pozostać na miejscu.
