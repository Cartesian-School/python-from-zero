# %% [markdown]
# # 08-10 · Mini-projekt – matematyka dynamiczna
#
# Praktyka do sekcji [„Mini-projekt – dynamiczna matematyka”

# %% [markdown]
# ## Cel
#
# Zbieranie danych wejściowych, liczb, łańcuch znaków f- w jednym mini-kalkulatorze (bez okna Turtle – tylko obliczenia i logika tekstu).

# %% [markdown]
# ## Pro input() w tym laptopie
#
# W normalnym życiu `.py`-plik `input()` czeka, aż wpiszesz i nacisniesz Enter. Ten laptop działa automatycznie, bez żywej osoby za klawiaturą – dlatego tu jest `input()` tymczasowo zastąpione gotowymi odpowiedziami. Sam kod `input()` poniżej wygląda i działa dokładnie jak zwykły plik, który sam uruchamiasz.

# %%
_answers = iter(['6', '7'])

def input(prompt=""):
    answer = next(_answers)
    print(prompt + answer)
    return answer

# %% [markdown]
# ## Sprawa robocza

# %%
a = float(input("Первое число: "))
b = float(input("Второе число: "))

print(f"{a} + {b} = {a + b}")
print(f"{a} * {b} = {a * b}")
# Out:
# Первое число: 6
# Второе число: 7
# 6.0 + 7.0 = 13.0
# 6.0 * 7.0 = 42.0

# %% [markdown]
# ## Pro input() w tym laptopie
#
# W normalnym życiu `.py`-plik `input()` czeka, aż wpiszesz i nacisniesz Enter. Ten laptop działa automatycznie, bez żywej osoby za klawiaturą – dlatego tu jest `input()` tymczasowo zastąpione gotowymi odpowiedziami. Sam kod `input()` poniżej wygląda i działa dokładnie jak zwykły plik, który sam uruchamiasz.

# %%
_answers = iter(['10', '4'])

def input(prompt=""):
    answer = next(_answers)
    print(prompt + answer)
    return answer

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Dodaj odejmowanie i dzielenie do wyniku.

# %%
a = float(input("Первое число: "))
b = float(input("Второе число: "))

print(f"{a} + {b} = {a + b}")
print(f"{a} - {b} = {a - b}")
print(f"{a} * {b} = {a * b}")
print(f"{a} / {b} = {a / b}")
# Out:
# Первое число: 10
# Второе число: 4
# 10.0 + 4.0 = 14.0
# 10.0 - 4.0 = 6.0
# 10.0 * 4.0 = 40.0
# 10.0 / 4.0 = 2.5
