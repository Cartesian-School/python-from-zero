# %% [markdown]
# # 08-07 · Wkład użytkownika
#
# Praktyka do sekcji ["Odbiór danych od użytkowników"](.. /.. /site/chapters/glava-08/08-07-vvod-polzovatelya.html) oraz ["Mini-projekt - tekst Turtle"](.. /.. /site/chapters/glava-08/08-08-mini-proekt-turtle-tekst.html).

# %% [markdown]
# ## Cel
#
# Opanować input() i przekształcić wpisany tekst w liczby.

# %% [markdown]
# ## Pro input() w tym laptopie
#
# W normalnym życiu `.py`-plik `input()` czeka, aż wpiszesz i nacisniesz Enter. Ten laptop działa automatycznie, bez żywej osoby za klawiaturą – dlatego tu jest `input()` tymczasowo zastąpione gotowymi odpowiedziami. Sam kod `input()` poniżej wygląda i działa dokładnie jak zwykły plik, który sam uruchamiasz.

# %%
_answers = iter(['Cartesian', '12', '25', 'Cartesian'])

def input(prompt=""):
    answer = next(_answers)
    print(prompt + answer)
    return answer

# %% [markdown]
# ## Sprawa robocza

# %%
name = input("Как вас зовут? ")
print(f"Привет, {name}!")
# Out:
# Как вас зовут? Cartesian
# Привет, Cartesian!

# %% [markdown]
# ## Eksperyment 1 — konwersja na liczbę

# %%
age_text = input("Сколько вам лет? ")
age = int(age_text)
print(f"Через 5 лет вам будет {age + 5}.")
# Out:
# Сколько вам лет? 12
# Через 5 лет вам будет 17.

# %% [markdown]
# ## Typowy błąd
#
# Bez `int()` łańcuch znaków i liczba się nie zgadzają.

# %%
age_text = input("Сколько вам лет? ")
age_text + 5
# Out:
# Сколько вам лет? 25
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 age_text = input("Сколько вам лет? ")
# ----> 2 age_text + 5
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Poprawka

# %%
age = int(age_text)
print(age + 5)
# Out:
# 30

# %% [markdown]
# ## Mini-projekt - Turtle tekstowy (bez okna, tylko logika)
#
# W obecnym programie ten łańcuch znaków dotarł do płótna przez `artist.write()` (Rozdział 7) — tutaj sprawdzimy tylko część tekstową.

# %%
name = input("Как вас зовут? ")
message = f"Привет, {name}!"
print(message)
# Out:
# Как вас зовут? Cartesian
# Привет, Cartesian!
