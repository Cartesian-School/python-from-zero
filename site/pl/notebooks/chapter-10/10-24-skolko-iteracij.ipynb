# %% [markdown]
# # 10-24 · Ile iteracji w zagnieżdżonej pętli?
#
# Praktyka do sekcji [„if w pętlach, zagnieżdżonych pętli”

# %% [markdown]
# ## Cel
#
# Ćwicz liczenie łącznej liczby iteracji zagnieżdżonej pętli: wiersze × kolumny.

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Zapisz zagnieżdżoną pętlę składającą się z 3 wierszy × 7 kolumn i policz liczbę wykonań ciała, zapisując wynik w `itogo_iteracij`.

# %%
schetchik = 0
for row in range(3):
    for col in range(7):
        schetchik += 1

itogo_iteracij = schetchik
print(itogo_iteracij)
# Out:
# 21
