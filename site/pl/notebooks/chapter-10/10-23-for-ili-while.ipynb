# %% [markdown]
# # 10-23 · for czy while – co wybrać?
#
# Praktyka do sekcji [„Cykle while”

# %% [markdown]
# ## Cel
#
# Konsolidacja wzorca wyboru między for a while.

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Dla każdej sytuacji zapisz właściwy wybór — w wierszu `"for"`, `"while"` lub `"while True"`:
#
# 1. Narysować wszystkie 4 strony kwadratu.
# 2. Powtarzać, dopóki użytkownik nie odgadnie liczby.
# 3. Przejdź przez wszystkie litery tego słowa.
# 4. Bardziej naturalne jest sprawdzenie stanu zatrzymania się w środku ciała.

# %%
otvet_1 = "for"
otvet_2 = "while"
otvet_3 = "for"
otvet_4 = "while True"
