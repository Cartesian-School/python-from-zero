# %% [markdown]
# # 14-24 · Praktyka: dataclass
#
# Praktyka do sekcji [„Praktyka: dataclass”

# %% [markdown]
# ## Cel
#
# Przepisz Tovar rozdziału 14.14 przez @dataclass i zgromadzić wokół niego Zakaz.

# %% [markdown]
# ## Sprawa robocza

# %%
from dataclasses import dataclass

@dataclass
class Tovar:
    nazvanie: str
    tsena: float

    def so_skidkoj(self, protsent):
        return self.tsena * (1 - protsent / 100)

knigi = Tovar("Книга", 590)
print(knigi)
print(knigi.so_skidkoj(10))

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Zdefiniuj `@dataclass Zakaz` z marginesami `tovar: Tovar` oraz `kolichestvo: int`i metoda `summa()`powrót `self.tovar.tsena * self.kolichestvo`.

# %%
@dataclass
class Zakaz:
    tovar: Tovar
    kolichestvo: int

    def summa(self):
        return self.tovar.tsena * self.kolichestvo

ruchka = Tovar("Ручка", 100)
zakaz = Zakaz(ruchka, 3)
print(zakaz.summa())
