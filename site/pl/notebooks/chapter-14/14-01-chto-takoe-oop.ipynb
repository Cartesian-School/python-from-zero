# %% [markdown]
# # 14-01 · Co to jest OOP?
#
# Praktyka do sekcji [„Czym jest programowanie obiektowe?”

# %% [markdown]
# ## Cel
#
# Rozpoznawanie obiektów w znanym kodzie.

# %% [markdown]
# ## Sprawa robocza

# %%
text = "Python"
print(type(text))          # str — это класс
print(text.upper())        # upper() — метод этого объекта
# Out:
# <class 'str'>
# PYTHON

# %% [markdown]
# ## Eksperyment 1
#
# Sprawdź klasę kilku już znanych obiektów.

# %%
for value in [42, 3.14, "текст", [1, 2, 3], {"a": 1}]:
    print(value, "->", type(value))
# Out:
# 42 -> <class 'int'>
# 3.14 -> <class 'float'>
# текст -> <class 'str'>
# [1, 2, 3] -> <class 'list'>
# {'a': 1} -> <class 'dict'>

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Znajdź trzy metody w liście (rozdział 11) i wyjaśnij własnymi słowami, co każda z nich robi.

# %%
numbers = [3, 1, 2]
numbers.append(4)   # добавляет элемент
numbers.sort()       # сортирует список
numbers.reverse()    # разворачивает список
print(numbers)
# Out:
# [4, 3, 2, 1]
