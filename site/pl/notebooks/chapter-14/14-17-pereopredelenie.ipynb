# %% [markdown]
# # 14-17 · Metody nadpisujące
#
# Praktyka do sekcji [„Metody nadpisowy”

# %% [markdown]
# ## Cel
#
# Rozszerz metodę rodzica przez super().method(), a nie zamieniaj jej w całości.

# %% [markdown]
# ## Sprawa robocza

# %%
class Zhivotnoe:
    def zvuk(self):
        return "Животное подаёт голос: "


class Sobaka(Zhivotnoe):
    def zvuk(self):
        return super().zvuk() + "Гав!"

print(Sobaka().zvuk())

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Utwórz klasę `Koshka(Zhivotnoe)`to nadpisuje `zvuk()` przez `super().zvuk()` i dodający „Miau!”.

# %%
class Koshka(Zhivotnoe):
    def zvuk(self):
        return super().zvuk() + "Мяу!"

print(Koshka().zvuk())
