# %% [markdown]
# # 13-22 · Refaktoryzacja quizu
#
# Praktyka do sekcji [„Refaktoryzacja szkiców rozdziału 12”

# %% [markdown]
# ## Cel
#
# Podziel quiz z rozdziału 12 na funkcje check_answer i run_quiz.

# %% [markdown]
# ## Podstawowa praktyka zadań ★

# %%
def check_answer(user_answer, correct_answer):
    return user_answer.strip().lower() == correct_answer.lower()

def run_quiz(questions, answers):
    score = 0
    for q, given in zip(questions, answers):
        if check_answer(given, q["answer"]):
            score += 1
    return score

questions = [{"answer": "paris"}, {"answer": "56"}]
answers = ["Paris", "56"]
final_score = run_quiz(questions, answers)
print(final_score)
# Out:
# 2
