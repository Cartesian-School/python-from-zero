# %% [markdown]
# # 13-18 · Kontrakt funkcji
#
# Praktyka do sekcji [„Projektowanie dobrej funkcji”

# %% [markdown]
# ## Cel
#
# Zaimplementuj funkcję według zadanego kontraktu.

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Umowa: calculate_discount(price, percent) to procent z rabatem.

# %%
def calculate_discount(price, percent):
    return price - price * percent / 100

d1 = calculate_discount(100, 10)
d2 = calculate_discount(200, 50)
print(d1, d2)
# Out:
# 90.0 100.0
