# %% [markdown]
# # 05-13 · Korzenie i odległości
#
# Praktyka do sekcji [„Korzenie i odległości”

# %% [markdown]
# ## Cel
#
# Opanować math.isqrt(), math.hypot() i math.dist() na zadaniach geometrycznych.

# %% [markdown]
# ## Sprawa robocza

# %%
import math
print(math.hypot(3, 4))
# Out:
# 5.0

# %% [markdown]
# ## Eksperyment 1
#
# Porównaj isqrt() z normalnym sqrt().

# %%
import math
print(math.sqrt(10))
print(math.isqrt(10))
# Out:
# 3.1622776601683795
# 3

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Znajdź odległość między punktami (0, 0) i (6, 8) przez math.dist() i wyjść wynik.

# %%
import math
A = (0, 0)
B = (6, 8)
print(math.dist(A, B))
# Out:
# 10.0
