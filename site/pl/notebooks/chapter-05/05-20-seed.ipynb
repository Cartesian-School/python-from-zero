# %% [markdown]
# # 05-20 · seed i powtarzalność
#
# Praktyka do sekcji [„seed i powtarzalność”](/pl/chapters/rozdzial-05/05-20-seed.html).

# %% [markdown]
# ## Cel
#
# Upewnić się, że ten sam seed daje tę samą sekwencję liczb losowych.

# %% [markdown]
# ## Sprawa robocza

# %%
import random
random.seed(42)
print(random.randint(1, 100))
random.seed(42)
print(random.randint(1, 100))
# Out:
# 82
# 82

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Fix `random.seed(5)`, wtedy wyjść `random.randint(1, 100)` (przewiduje się, że będzie 80 – ten sam wynik za każdym razem, gdy seed).

# %%
import random
random.seed(5)
print(random.randint(1, 100))
# Out:
# 80
