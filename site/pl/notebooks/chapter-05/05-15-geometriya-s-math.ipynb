# %% [markdown]
# # 05-15 · Geometria z math
#
# Praktyka do sekcji [„Geometria z math”

# %% [markdown]
# ## Cel
#
# Oblicz pole i obwód okręgu w math.pi.

# %% [markdown]
# ## Sprawa robocza

# %%
import math
radius = 4
print(round(math.pi * radius ** 2, 2))
# Out:
# 50.27

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Oblicz pole okręgu o promieniu 10, zaokrągli do 2 cyfr i wynik (oczekiwane 314,16).

# %%
import math
radius = 10
ploshad = math.pi * radius ** 2
print(round(ploshad, 2))
# Out:
# 314.16
