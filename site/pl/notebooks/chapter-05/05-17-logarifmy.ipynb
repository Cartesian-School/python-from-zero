# %% [markdown]
# # 05-17 · Logarytmy i wykładniki
#
# Praktyka do sekcji [„Logarytmy i wykładniki”

# %% [markdown]
# ## Cel
#
# Zrozumieć logarytm jako operację odwrotną do potęgi.

# %% [markdown]
# ## Sprawa robocza

# %%
import math
print(2 ** 3)
print(math.log2(8))
# Out:
# 8
# 3.0

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Oblicz log2(1024) i wyświetl wynik (przewidywany na 10,0).

# %%
import math
print(math.log2(1024))
# Out:
# 10.0
