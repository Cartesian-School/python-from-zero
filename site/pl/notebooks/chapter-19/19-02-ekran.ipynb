# %% [markdown]
# # 19-02 · Ekran i zmienne
#
# Praktyka do sekcji [„Ustawianie ekranu Turtle i zmiennych”

# %% [markdown]
# ## Cel
#
# Dostosuj ekran tracer(0) i ustaw zmienne stanu.

# %% [markdown]
# ## Ustawienie (wykonać raz)

# %%
import turtle

RAZMER_SHAGA = 20
GRANICA = 280

screen = turtle.Screen()
screen.title("Змейка")
screen.bgcolor("black")
screen.setup(width=600, height=600)
screen.tracer(0)
print("Экран готов.")
# Out:
# Экран готов.

# %% [markdown]
# ## Sprawa robocza

# %%
napravlenie = "stop"
schet = 0
igra_okonchena = False
segmenty = []

print("Направление:", napravlenie)
print("Счёт:", schet)
print("Игра окончена:", igra_okonchena)
# Out:
# Направление: stop
# Счёт: 0
# Игра окончена: False

# %% [markdown]
# ## Ukończenie (wykonaj raz, na samym końcu)

# %%
screen.bye()
print("Окно закрыто.")
# Out:
# Окно закрыто.
