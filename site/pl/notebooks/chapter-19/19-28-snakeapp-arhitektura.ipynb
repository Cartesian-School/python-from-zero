# %% [markdown]
# # 19-28 · SnakeApp: oddzielenie modelu od wizualizacji
#
# Praktyka do sekcji [„SnakeApp: oddzielić model od wizualizacji”

# %% [markdown]
# ## Cel
#
# Zebrać mini-obiekt aplikacji: state oddzielnie od Turtle- widgetów.

# %% [markdown]
# ## Ustawienie (wykonać raz)

# %%
import turtle

RAZMER_SHAGA = 20
GRANICA = 280

screen = turtle.Screen()
screen.title("Змейка")
screen.bgcolor("black")
screen.setup(width=600, height=600)
screen.tracer(0)
print("Экран готов.")
# Out:
# Экран готов.

# %% [markdown]
# ## Sprawa robocza

# %%
class MiniSnakeApp:
    def __init__(self):
        self.state = {"snake": [(0, 0)], "score": 0}
        self.head = turtle.Turtle()
        self.head.speed(0)
        self.head.shape("square")
        self.head.penup()

    def render(self):
        self.head.goto(*self.state["snake"][0])
        screen.update()

app = MiniSnakeApp()
app.state["snake"] = [(40, 0)]
app.render()
print("app.state — обычный словарь; app.head — единственный Turtle-объект.")
# Out:
# app.state — обычный словарь; app.head — единственный Turtle-объект.

# %% [markdown]
# ## Sprawdzenie wyniku

# %%
assert app.state["snake"] == [(40, 0)]
assert isinstance(app.head, turtle.Turtle)
assert app.head.position() == (40.0, 0.0)
print("Модель (state) и виджет (head) — разные атрибуты, не одно и то же.")
# Out:
# Модель (state) и виджет (head) — разные атрибуты, не одно и то же.

# %% [markdown]
# ## Ukończenie (wykonaj raz, na samym końcu)

# %%
screen.bye()
print("Окно закрыто.")
# Out:
# Окно закрыто.
