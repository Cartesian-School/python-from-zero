# %% [markdown]
# # 06-04 · Mini-projekty: kwadrat i sześciokąt
#
# Praktyka do sekcji [„Mini-projekty: kwadrat i heksagon”

# %% [markdown]
# ## Cel
#
# Narysuj pierwsze rzeczywiste kształty: kwadrat i sześciokąt.

# %% [markdown]
# ## Ustawienie (wykonać raz)

# %%
import turtle

screen = turtle.Screen()
artist = turtle.Turtle()
artist.speed(0)
print("Окно Turtle готово.")
# Out:
# Окно Turtle готово.

# %% [markdown]
# ## Przykład roboczy – Square

# %%
artist.reset()
for _ in range(4):
    artist.forward(100)
    artist.right(90)
print("Курс после квадрата:", artist.heading())
# Out:
# Курс после квадрата: 0.0

# %% [markdown]
# ## Eksperyment 1 — sześciokąt
#
# Kąt obrotu = 360 / liczba boków.

# %%
artist.reset()
for _ in range(6):
    artist.forward(80)
    artist.right(60)
print("Курс после шестиугольника:", artist.heading())
# Out:
# Курс после шестиугольника: 0.0

# %% [markdown]
# ## Eksperyment 2
#
# Spróbuj formuły `360 / n` trójkąt (n=3) i ośmiokąt (n=8).

# %%
for n in [3, 8]:
    artist.reset()
    ugol = 360 / n
    for _ in range(n):
        artist.forward(70)
        artist.right(ugol)
    print(f"n={n}: угол поворота = {ugol}°")
# Out:
# n=3: угол поворота = 120.0°
# n=8: угол поворота = 45.0°

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Narysuj regularny pięciokąt według wzoru `360 / n`.

# %%
artist.reset()
n = 5
ugol = 360 / n
for _ in range(n):
    artist.forward(90)
    artist.right(ugol)
print("Пятиугольник готов, угол поворота был", ugol, "градусов")
# Out:
# Пятиугольник готов, угол поворота был 72.0 градусов

# %% [markdown]
# ## Sprawdzenie wyniku

# %%
assert 360 / 5 == 72.0
print("Верно: для пятиугольника угол поворота 72°.")
# Out:
# Верно: для пятиугольника угол поворота 72°.

# %% [markdown]
# ## Zadanie dodatkowe ★★★
#
# Napisz kształt z n=20 bokami – jak to wygląda?

# %%
artist.reset()
n = 20
ugol = 360 / n
for _ in range(n):
    artist.forward(30)
    artist.right(ugol)
print("20-угольник почти неотличим от окружности!")
# Out:
# 20-угольник почти неотличим от окружности!

# %% [markdown]
# ## Ukończenie (wykonaj raz, na samym końcu)

# %%
screen.bye()
print("Окно Turtle закрыто.")
# Out:
# Окно Turtle закрыто.
