# %% [markdown]
# # 06-20 · Formuła 360/n
#
# Praktyka do sekcji [„Pierwsze liczby i wzór 360/n”

# %% [markdown]
# ## Cel
#
# Oblicz kąt obrotu dla wielokąta regularnego o dowolnej liczbie boków.

# %% [markdown]
# ## Sprawa robocza

# %%
n = 6
povorot = 360 / n
print(povorot)
# Out:
# 60.0

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Oblicz kąt obrotu dla heksagonu (n=9) i dwunastokąta (n=12). Wyjdź obie liczby oddzielone przestrzenią o jeden print().

# %%
povorot_9 = 360 / 9
povorot_12 = 360 / 12
print(povorot_9, povorot_12)
# Out:
# 40.0 30.0
