# %% [markdown]
# # 11-09 · Mini-projekt - nieskończone kolory
#
# Praktyka do sekcji [„Mini-projekt - nieskończone kolory”

# %% [markdown]
# ## Cel
#
# Słownik jako mapa korespondencji + Turtle.

# %% [markdown]
# ## Ustawienie (wykonać raz)

# %%
import turtle

screen = turtle.Screen()
artist = turtle.Turtle()
artist.speed(0)
print("Окно Turtle готово.")
# Out:
# Окно Turtle готово.

# %% [markdown]
# ## Sprawa robocza

# %%
artist.reset()
cvetovaya_karta = {"огонь": "red", "трава": "green", "небо": "blue"}

zapros = "небо"
artist.pencolor(cvetovaya_karta[zapros])
artist.circle(50)
print("Нарисовано цветом:", cvetovaya_karta[zapros])
# Out:
# Нарисовано цветом: blue

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Dodaj pary słów-kolorów i narysuj kształt dla każdej z nich.

# %%
artist.reset()
cvetovaya_karta = {
    "огонь": "red", "трава": "green", "небо": "blue",
    "солнце": "yellow", "ночь": "purple",
}

artist.penup()
for i, (slovo, cvet) in enumerate(cvetovaya_karta.items()):
    artist.goto(i * 60 - 120, 0)
    artist.pendown()
    artist.pencolor(cvet)
    artist.circle(20)
    artist.penup()

print("Нарисовано", len(cvetovaya_karta), "кругов.")
# Out:
# Нарисовано 5 кругов.

# %% [markdown]
# ## Ukończenie (wykonaj raz, na samym końcu)

# %%
screen.bye()
print("Окно Turtle закрыто.")
# Out:
# Окно Turtle закрыто.
