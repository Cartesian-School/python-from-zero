# %% [markdown]
# # 12-09 · Zgadnij liczbę, wersja 3
#
# Praktyka do sekcji [„Project: Guess the Number, Version 3”

# %% [markdown]
# ## Cel
#
# Pełna gra zgadywania: while, if/elif/else, spróbuj kontrować.

# %% [markdown]
# ## O losowości w tym laptopie
#
# Tutaj rejestrowany jest tajny numer (`secret = 37`) zamiast wybierać losowo, w przeciwnym razie automatyczny test wyników byłby niedeterministyczny.

# %% [markdown]
# ## Pro input() w tym laptopie
#
# Ten laptop jest automatyczny, więc `input()` tymczasowo zastąpione wcześniej przygotowanymi odpowiedziami.

# %%
_answers = iter(['50', '25', '37'])

def input(prompt=""):
    answer = next(_answers)
    print(prompt + answer)
    return answer

# %% [markdown]
# ## Sprawa robocza

# %%
secret = 37
attempts = 0
guess = None

while guess != secret:
    guess = int(input("Ваша попытка: "))
    attempts += 1
    if guess < secret:
        print("Слишком мало!")
    elif guess > secret:
        print("Слишком много!")
    else:
        print(f"Поздравляем! Загадано было {secret}. Попыток: {attempts}")
# Out:
# Ваша попытка: 50
# Слишком много!
# Ваша попытка: 25
# Слишком мало!
# Ваша попытка: 37
# Поздравляем! Загадано было 37. Попыток: 3
