# %% [markdown]
# # 16-01 · Przygotowanie Tkinter
#
# Praktyka do sekcji [„Tkinter — wszystko poprawnie ustawiamy!”](/pl/chapters/rozdzial-16/16-01-nastraivaem-tkinter.html).)

# %% [markdown]
# ## Cel
#
# Utwórz pierwsze okno Tkinter.

# %% [markdown]
# ## Pro mainloop() w tym laptopie
#
# W normalnym życiu `.py`- pliku aplikacja jest uruchamiana przez `root.mainloop()` - To polecenie „zamraża” `root.mainloop()` zadzwonimy `root.update()` (obsługuje zdarzenia raz, bez oczekiwania) a następnie `root.destroy()` — interfejs buduje się dokładnie tak samo, po prostu bez nieskończonego oczekiwania na końcu.

# %% [markdown]
# ## Sprawa robocza

# %%
import tkinter as tk

root = tk.Tk()
root.title("Моё первое приложение")
root.geometry("400x300")

print("Заголовок окна:", root.title())
root.update()
root.destroy()
print("Окно закрыто.")
# Out:
# Заголовок окна: Моё первое приложение
# Окно закрыто.

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Stwórz okno 300x200 z tytułem.

# %%
root = tk.Tk()
root.title("Окно Cartesian")
root.geometry("300x200")

print(root.title(), root.geometry())
root.update()
root.destroy()
# Out:
# Окно Cartesian 1x1+0+0
