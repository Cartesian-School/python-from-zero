# %% [markdown]
# # 16-22 · after() i timery
#
# Praktyka do sekcji [„after(): timery bez blokady”](/pl/chapters/rozdzial-16/16-22-after-tajmery.html).

# %% [markdown]
# ## Cel
#
# Stwórz powtarzający się timer co after() i zatrzymaj to.

# %% [markdown]
# ## Pro mainloop() w tym laptopie
#
# W normalnym życiu `.py`- pliku aplikacja jest uruchamiana przez `root.mainloop()` - To polecenie „zamraża” `root.mainloop()` zadzwonimy `root.update()` (obsługuje zdarzenia raz, bez oczekiwania) a następnie `root.destroy()` — interfejs buduje się dokładnie tak samo, po prostu bez nieskończonego oczekiwania na końcu.

# %%
import tkinter as tk
from tkinter import ttk

root = tk.Tk()
schet = tk.IntVar(value=0)
label = ttk.Label(root, textvariable=schet)
label.pack()

def tik():
    schet.set(schet.get() + 1)

# programowo wywoływać tik() wielokrotnie zamiast faktycznie czekać kilka sekund
tik()
tik()
tik()
root.update()
print("Значение после трёх тиков:", schet.get())
root.destroy()
# Out:
# Значение после трёх тиков: 3
