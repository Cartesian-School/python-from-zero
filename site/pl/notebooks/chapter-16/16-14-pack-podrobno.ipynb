# %% [markdown]
# # 16-14 · pack szczegóły
#
# Praktyka do sekcji [„pack szczegółowo: fill, expand i zagnieżdżone ramki”](/pl/chapters/rozdzial-16/16-14-pack-podrobno.html).

# %% [markdown]
# ## Cel
#
# Mistrz fill i expand z pack().

# %% [markdown]
# ## Pro mainloop() w tym laptopie
#
# W normalnym życiu `.py`- pliku aplikacja jest uruchamiana przez `root.mainloop()` - To polecenie „zamraża” `root.mainloop()` zadzwonimy `root.update()` (obsługuje zdarzenia raz, bez oczekiwania) a następnie `root.destroy()` — interfejs buduje się dokładnie tak samo, po prostu bez nieskończonego oczekiwania na końcu.

# %%
import tkinter as tk
from tkinter import ttk

root = tk.Tk()

forma_frame = ttk.Frame(root, padding=10)
forma_frame.pack(fill="x")

ttk.Label(forma_frame, text="Имя:").pack(side="left")
entry = ttk.Entry(forma_frame)
entry.pack(side="left", fill="x", expand=True)

root.update()
print(entry.winfo_manager())
root.destroy()
# Out:
# pack
