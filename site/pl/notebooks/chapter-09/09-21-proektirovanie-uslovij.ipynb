# %% [markdown]
# # 09-21 · Projektowanie warunków
#
# Praktyka do sekcji [„Projektowanie warunku: input, validation, boundaries”

# %% [markdown]
# ## Cel
#
# Zobacz off-by-one błąd na granicach zasięgu.

# %% [markdown]
# ## Sprawa robocza

# %%
number = 1
print(1 <= number <= 10)
print(1 < number < 10)
# Out:
# True
# False

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Porównaj poprawny (włącznie) i nieprawidłowy (ścisły) test brzegowy dla number = 1.

# %%
number = 1
in_range_correct = 1 <= number <= 10
in_range_buggy = 1 < number < 10
print(in_range_correct, in_range_buggy)
# Out:
# True False
