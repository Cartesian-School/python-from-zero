# %% [markdown]
# # 07-24 · Wzór dla circle(steps=...)
#
# Praktyka do sekcji [„circle(steps=...) — z okręgu do wielokąta”

# %% [markdown]
# ## Cel
#
# Obliczyć kąt obrotu wielokąta przybliżającego okrąg dla różnej liczby steps.

# %% [markdown]
# ## Sprawa robocza

# %%
steps = 5
povorot = 360 / steps
print(povorot)
# Out:
# 72.0

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Oblicz kąt obrotu dla circle(80, steps=3), circle(80, steps=4) i circle(80, steps=8). Wyświetl wszystkie trzy liczby oddzielone spacją w jednej print().

# %%
povorot_3 = 360 / 3
povorot_4 = 360 / 4
povorot_8 = 360 / 8
print(povorot_3, povorot_4, povorot_8)
# Out:
# 120.0 90.0 45.0
