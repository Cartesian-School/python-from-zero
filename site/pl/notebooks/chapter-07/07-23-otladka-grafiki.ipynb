# %% [markdown]
# # 07-23 · Debugowanie grafiki
#
# Praktyka do sekcji [„Debugowanie grafik”

# %% [markdown]
# ## Cel
#
# Zrozumieć, do czego prowadzi zapomniany screen.update() po tracer(0).

# %% [markdown]
# ## Sprawa robocza
#
# Jeśli tracer(0) jest zainstalowany, a update() nie wywołano ani razu, ile razy ekran pokazał wynik losowania?

# %%
# tracer(0) całkowicie wyłącza aktualizacje pośrednie
# bez żadnego update() ekran NIGDY nie pokaże tego, co zostało narysowane
pokazy = 0
print(pokazy)
# Out:
# 0

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Program wywołuje screen.tracer(0), rysuje 100 poleceń, ale NIE wywołuje screen.update() ani razu. Ile razy odświeży się ekran? Wyświetl numer.

# %%
kolichestvo_obnovlenij = 0
print(kolichestvo_obnovlenij)
# Out:
# 0
