# %% [markdown]
# # 15-24 · Jak wybrać format przechowywania danych
#
# Praktyka do sekcji [„Jak wybrać format przechowywania danych”

# %% [markdown]
# ## Podstawowa praktyka zadań ★
#
# Dla każdego zadania wybierz odpowiedni format pamięci: "tekst", "CSV" lub "JSON".

# %%
# ustawienia aplikacji (struktura zagnieżdżona: motyw, język, rozmiar okna)
vybor_dlya_nastroek = "JSON"

# tabela wyników zawodników (identyczne linie: imię, punkty, poziom)
vybor_dlya_tablitsy_rezultatov = "CSV"

# łatwe lista nuty, po jednej na linijkę
vybor_dlya_zametok = "текст"

print(vybor_dlya_nastroek, vybor_dlya_tablitsy_rezultatov, vybor_dlya_zametok)
# Out:
# JSON CSV текст
