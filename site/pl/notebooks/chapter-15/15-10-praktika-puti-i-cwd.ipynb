# %% [markdown]
# # 15-10 · Praktyka: Ścieżki i CWD
#
# Praktyka do sekcji [„Praktyka: Ścieżki i CWD”

# %% [markdown]
# ## Przypadek roboczy – ścieżka względem folderu bazowego

# %%
from pathlib import Path

BASE_DIR = Path.cwd()
data_dir = BASE_DIR / "data"
data_dir.mkdir(exist_ok=True)

file_path = data_dir / "otchet.txt"
file_path.unlink(missing_ok=True)   # для повторяемости примера при повторном запуске
existed_before = file_path.exists()
file_path.write_text("готово", encoding="utf-8")
existed_after = file_path.exists()
print(existed_before, existed_after)
# Out:
# False True

# %% [markdown]
# ## Zadanie niezależne od zadania ★★
#
# Zbuduj ścieżkę do rodzica `data_dir` i upewnij się, że to ta sama ścieżka co `BASE_DIR.parent`.

# %%
from pathlib import Path

BASE_DIR = Path.cwd()
data_dir = BASE_DIR / "data"
sovpadaet = data_dir.parent.parent == BASE_DIR.parent
print(sovpadaet)
# Out:
# True
