# %% [markdown]
# # 09-05 · Мини-проект — «Угадай число»
#
# Практика к разделу [«Мини-проект — игра «Угадай число»»](../../site/chapters/glava-09/09-05-mini-proekt-ugadaj-chislo.html).

# %% [markdown]
# ## Цель
#
# Собрать первую мини-игру книги.

# %% [markdown]
# ## О случайности в этом ноутбуке
#
# Игра использует `random.randint()`, поэтому результат зависит от случайного числа. Чтобы
# ноутбук выполнялся предсказуемо (и его можно было автоматически проверить), здесь мы
# дополнительно закрепляем случайность через `random.seed()` — в обычной игре это не нужно.

# %% [markdown]
# ## Про input() в этом ноутбуке
#
# В обычном `.py`-файле `input()` ждёт, пока вы наберёте текст и нажмёте Enter. Этот ноутбук выполняется автоматически, без живого человека за клавиатурой — поэтому здесь `input()` временно подменён на заранее заготовленные ответы. Сам код с `input()` ниже выглядит и работает точно так же, как в обычном файле, который вы запускаете сами.

# %%
_answers = iter(['10'])

def input(prompt=""):
    answer = next(_answers)
    print(prompt + answer)
    return answer

# %% [markdown]
# ## Рабочий пример

# %%
import random

random.seed(42)  # закрепляем случайность для повторяемого результата в ноутбуке
zagadannoe = random.randint(1, 20)
popytka = int(input("Угадайте число от 1 до 20: "))

if popytka == zagadannoe:
    print("Поздравляем, вы угадали!")
elif popytka < zagadannoe:
    print(f"Мимо! Загаданное число больше, чем {popytka}.")
else:
    print(f"Мимо! Загаданное число меньше, чем {popytka}.")

print(f"Загаданное число было: {zagadannoe}")
# Out:
# Угадайте число от 1 до 20: 10
# Мимо! Загаданное число меньше, чем 10.
# Загаданное число было: 4

# %% [markdown]
# ## Про input() в этом ноутбуке
#
# В обычном `.py`-файле `input()` ждёт, пока вы наберёте текст и нажмёте Enter. Этот ноутбук выполняется автоматически, без живого человека за клавиатурой — поэтому здесь `input()` временно подменён на заранее заготовленные ответы. Сам код с `input()` ниже выглядит и работает точно так же, как в обычном файле, который вы запускаете сами.

# %%
_answers = iter(['8'])

def input(prompt=""):
    answer = next(_answers)
    print(prompt + answer)
    return answer

# %% [markdown]
# ## Задание ★★ Самостоятельная задача
#
# Добавьте подсказку «Очень близко!», если разница между попыткой и загаданным числом меньше 3.

# %%
import random

random.seed(42)
zagadannoe = random.randint(1, 20)
popytka = int(input("Угадайте число от 1 до 20: "))

if popytka == zagadannoe:
    print("Поздравляем, вы угадали!")
elif abs(popytka - zagadannoe) < 3:
    print("Очень близко!")
elif popytka < zagadannoe:
    print(f"Мимо! Загаданное число больше, чем {popytka}.")
else:
    print(f"Мимо! Загаданное число меньше, чем {popytka}.")

print(f"Загаданное число было: {zagadannoe}")
# Out:
# Угадайте число от 1 до 20: 8
# Мимо! Загаданное число меньше, чем 8.
# Загаданное число было: 4
