# %% [markdown]
# # 09-16 · not
#
# Практика к разделу [«not — переворачиваем условие»](../../site/chapters/glava-09/09-16-not.html).

# %% [markdown]
# ## Цель
#
# Освоить not — инверсию логического значения.

# %% [markdown]
# ## Рабочий пример

# %%
is_raining = False
print(not is_raining)
# Out:
# True

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Постройте can_walk через not, и проверьте двойное not.

# %%
is_raining = False
can_walk = not is_raining
double_negative = not not True
print(can_walk, double_negative)
# Out:
# True True
