# %% [markdown]
# # 09-07 · Алгоритмы и команды
#
# Практика к разделу [«Алгоритмы и команды»](../../site/chapters/glava-09/09-07-algoritmy-i-komandy.html).

# %% [markdown]
# ## Цель
#
# Проследить последовательное выполнение команд и предсказать значения переменных.

# %% [markdown]
# ## Рабочий пример

# %%
print("Старт")
x = 5
print(x)
print("Конец")
# Out:
# Старт
# 5
# Конец

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Проследите программу вручную (не запуская), предскажите значения `b` и `c`, затем проверьте себя.

# %%
a = 5
b = a + 3
c = b * 2
print(b, c)
# Out:
# 8 16
