# %% [markdown]
# # 10-23 · for или while — что выбрать?
#
# Практика к разделу [«Циклы while»](../../site/chapters/glava-10/10-03-perebor-strok-while.html).

# %% [markdown]
# ## Цель
#
# Закрепить ориентир выбора между for и while.

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Для каждой ситуации запишите правильный выбор — строкой `"for"`, `"while"` или `"while True"`:
#
# 1. Нарисовать все 4 стороны квадрата.
# 2. Повторять, пока пользователь не угадает число.
# 3. Перебрать все буквы слова.
# 4. Условие остановки естественнее проверить в середине тела.

# %%
otvet_1 = "for"
otvet_2 = "while"
otvet_3 = "for"
otvet_4 = "while True"
