# %% [markdown]
# # 10-24 · Сколько итераций во вложенном цикле?
#
# Практика к разделу [«if внутри циклов, вложенные циклы»](../../site/chapters/glava-10/10-02-if-vlozhennye-cikly.html#vlozhennye).

# %% [markdown]
# ## Цель
#
# Потренироваться считать общее число итераций вложенного цикла: строки × столбцы.

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Напишите вложенный цикл на 3 строки × 7 столбцов и посчитайте, сколько раз выполнится тело, сохранив результат в `itogo_iteracij`.

# %%
schetchik = 0
for row in range(3):
    for col in range(7):
        schetchik += 1

itogo_iteracij = schetchik
print(itogo_iteracij)
# Out:
# 21
