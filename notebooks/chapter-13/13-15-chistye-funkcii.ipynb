# %% [markdown]
# # 13-15 · Чистые функции и побочные эффекты
#
# Практика к разделу [«Вход, работа, выход: чистые функции»](../../site/chapters/glava-13/13-15-funkcii-vhod-vyhod.html).

# %% [markdown]
# ## Цель
#
# Отличить чистую функцию от функции с побочным эффектом.

# %% [markdown]
# ## Задание ★ Базовая практика

# %%
def rectangle_area(width, height):
    return width * height

log = []

def draw_square_effect(size):
    log.append(f"Нарисован квадрат {size}")

area = rectangle_area(4, 5)
draw_square_effect(10)

print(area, log)
# Out:
# 20 ['Нарисован квадрат 10']
