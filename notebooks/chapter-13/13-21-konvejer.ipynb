# %% [markdown]
# # 13-21 · Конвейер функций
#
# Практика к разделу [«Функции как конвейер»](../../site/chapters/glava-13/13-21-funkcii-kak-konvejer.html).

# %% [markdown]
# ## Цель
#
# Построить конвейер: результат одной функции становится входом следующей.

# %% [markdown]
# ## Задание ★ Базовая практика

# %%
def normalize_text(text):
    return text.lower()

def split_words(text):
    return text.split()

def count_words(words):
    return len(words)

pipeline_result = count_words(split_words(normalize_text("Python IS Fun")))
print(pipeline_result)
# Out:
# 3
