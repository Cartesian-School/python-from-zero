# %% [markdown]
# # 13-19 · Докстринги и типы
#
# Практика к разделу [«Докстринги и подсказки типов»](../../site/chapters/glava-13/13-19-dokumentaciya-i-tipy.html).

# %% [markdown]
# ## Цель
#
# Написать функцию с докстрингом и аннотациями типов.

# %% [markdown]
# ## Задание ★ Базовая практика

# %%
def rectangle_area(width: float, height: float) -> float:
    """Возвращает площадь прямоугольника."""
    return width * height

docstring_present = rectangle_area.__doc__ is not None
area = rectangle_area(3, 4)
print(docstring_present, area)
# Out:
# True 12
