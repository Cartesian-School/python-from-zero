# %% [markdown]
# # 13-10 · Порядок вызова
#
# Практика к разделу [«Что происходит во время вызова»](../../site/chapters/glava-13/13-10-vyzov-i-vozvrat-upravlenie.html).

# %% [markdown]
# ## Цель
#
# Предсказать порядок вывода при вызове функции.

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Предскажите порядок строк, прежде чем запускать.

# %%
def b():
    print("B")

def a():
    print("A1")
    b()
    print("A2")

print("Старт")
a()
print("Конец")
# Out:
# Старт
# A1
# B
# A2
# Конец
