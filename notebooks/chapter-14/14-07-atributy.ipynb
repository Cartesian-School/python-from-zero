# %% [markdown]
# # 14-07 · Атрибуты экземпляра и класса
#
# Практика к разделу [«Атрибуты экземпляра и класса»](../../site/chapters/glava-14/14-07-atributy-ekzemplyara-i-klassa.html).

# %% [markdown]
# ## Цель
#
# Отличить атрибут класса (общий) от атрибута экземпляра (свой).

# %% [markdown]
# ## Рабочий пример

# %%
class Sobaka:
    vid = "Собака"

    def __init__(self, klichka):
        self.klichka = klichka

rex = Sobaka("Рекс")
sharik = Sobaka("Шарик")
print(rex.vid, sharik.vid)

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Создайте класс `Rabotnik` с атрибутом класса `company = "Cartesian School"` и атрибутом экземпляра `imya`. Создайте `w1` и `w2`, затем присвойте `w1.company` новое значение напрямую — `w2.company` не должно измениться.

# %%
class Rabotnik:
    company = "Cartesian School"

    def __init__(self, imya):
        self.imya = imya

w1 = Rabotnik("Аня")
w2 = Rabotnik("Боря")
w1.company = "Другая компания"
print(w1.company, w2.company, Rabotnik.company)
