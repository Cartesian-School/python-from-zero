# %% [markdown]
# # 14-18 · Полиморфизм
#
# Практика к разделу [«Полиморфизм»](../../site/chapters/glava-14/14-18-polimorfizm.html).

# %% [markdown]
# ## Цель
#
# Один вызов метода — разное поведение в зависимости от класса объекта.

# %% [markdown]
# ## Рабочий пример

# %%
class Sobaka:
    def zvuk(self):
        return "Гав!"


class Koshka:
    def zvuk(self):
        return "Мяу!"


class Korova:
    def zvuk(self):
        return "Му!"


def poluchit_zvuk(zhivotnoe):
    return zhivotnoe.zvuk()

zhivotnye = [Sobaka(), Koshka(), Korova()]
zvuki = [poluchit_zvuk(zh) for zh in zhivotnye]
print(zvuki)

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Проверьте `poluchit_zvuk()` на каждом классе по отдельности.

# %%
zvuk_sobaki = poluchit_zvuk(Sobaka())
zvuk_koshki = poluchit_zvuk(Koshka())
zvuk_korovy = poluchit_zvuk(Korova())
print(zvuk_sobaki, zvuk_koshki, zvuk_korovy)
