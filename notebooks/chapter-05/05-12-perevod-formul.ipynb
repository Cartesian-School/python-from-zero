# %% [markdown]
# # 05-12 · Перевод формул: математика → Python
#
# Практика к разделу [«Перевод формул: математика → Python»](../../site/chapters/glava-05/05-12-perevod-formul.html).

# %% [markdown]
# ## Цель
#
# Перевести формулу x² + 2x + 1 из математической записи в Python.

# %% [markdown]
# ## Рабочий пример

# %%
x = 3
print(x ** 2 + 2 * x + 1)
# Out:
# 16

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Переведите формулу x² + 2x + 1 в Python для x = 5 и выведите результат (ожидается 36).

# %%
x = 5
rezultat = x ** 2 + 2 * x + 1
print(rezultat)
# Out:
# 36
