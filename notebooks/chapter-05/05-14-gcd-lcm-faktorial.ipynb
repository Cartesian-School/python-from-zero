# %% [markdown]
# # 05-14 · gcd, lcm, факториал, comb, perm
#
# Практика к разделу [«gcd, lcm, факториал, comb, perm»](../../site/chapters/glava-05/05-14-gcd-lcm-faktorial.html).

# %% [markdown]
# ## Цель
#
# Освоить пять функций math для целых чисел и подсчёта вариантов.

# %% [markdown]
# ## Рабочий пример

# %%
import math
print(math.gcd(12, 18))
print(math.lcm(4, 6))
# Out:
# 6
# 12

# %% [markdown]
# ## Эксперимент 1
#
# Сравните comb() и perm() для одних и тех же чисел.

# %%
import math
print(math.comb(6, 2))
print(math.perm(6, 2))
# Out:
# 15
# 30

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Найдите НОД(48, 18) и число сочетаний из 6 по 2 — выведите оба числа через пробел одним print() (ожидается `6 15`).

# %%
import math
print(math.gcd(48, 18), math.comb(6, 2))
# Out:
# 6 15
