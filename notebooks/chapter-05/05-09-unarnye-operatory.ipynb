# %% [markdown]
# # 05-09 · Унарные операторы
#
# Практика к разделу [«Унарные операторы»](../../site/chapters/glava-05/05-09-unarnye-operatory.html).

# %% [markdown]
# ## Цель
#
# Разобраться, почему -2 ** 2 не равно (-2) ** 2.

# %% [markdown]
# ## Рабочий пример

# %%
print(-2 ** 2)
print((-2) ** 2)
# Out:
# -4
# 4

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Выведите `-3 ** 2` и `(-3) ** 2` через пробел одним print() — числа должны быть разными.

# %%
print(-3 ** 2, (-3) ** 2)
# Out:
# -9 9
