# %% [markdown]
# # 17-30 · Visual effects и after()
#
# Практика к разделу [«Visual effects и after()»](../../site/chapters/glava-17/17-30-visual-effects-after.html).

# %% [markdown]
# ## Цель
#
# Собрать короткую неблокирующую анимацию победной линии через self-rescheduling after().

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# Вместо `root.mainloop()` здесь используется `root.update()` + `root.destroy()` — приложение строится точно так же, просто без бесконечного ожидания в конце (см. объяснение в ноутбуках главы 16).

# %% [markdown]
# ## Рабочий пример

# %%
import tkinter as tk

root = tk.Tk()
buttons = [tk.Button(root, text="X") for _ in range(3)]
for b in buttons:
    b.pack(side="left")

ticks_seen = []

def pulse(tick=0):
    ticks_seen.append(tick)
    color = "#6EE7B7" if tick % 2 == 0 else "#D1FAE5"
    for b in buttons:
        b.config(bg=color)
    if tick < 3:
        root.after(10, pulse, tick + 1)

pulse()
root.update()
root.after(80, root.quit)
root.mainloop()

print("Тиков анимации:", ticks_seen)
root.destroy()
# Out:
# Тиков анимации: [0, 1, 2, 3]

# %% [markdown]
# ## Задание ★★ Самостоятельная задача
#
# Добавьте `cancel_pulse()`, который вызывает `root.after_cancel(job_id)`, и проверьте, что после отмены анимация не продолжается.
