# %% [markdown]
# # 17-01 · Привязка событий
#
# Практика к разделу [«Привязка событий»](../../site/chapters/glava-17/17-01-privyazka-sobytij.html).

# %% [markdown]
# ## Цель
#
# Освоить .bind() для реакции на события клавиатуры.

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# Вместо `root.mainloop()` здесь используется `root.update()` + `root.destroy()` — приложение строится точно так же, просто без бесконечного ожидания в конце (см. объяснение в ноутбуках главы 16).

# %% [markdown]
# ## Рабочий пример

# %%
import tkinter as tk

root = tk.Tk()
label = tk.Label(root, text="Нажмите любую клавишу", font=("Arial", 14))
label.pack(padx=20, pady=20)

nazhatiya = []

def na_klavishu(event):
    nazhatiya.append(event.keysym)
    label.config(text=f"Вы нажали: {event.keysym}")

root.bind("<Key>", na_klavishu)
root.update()
root.focus_force()   # без фокуса окна event_generate для клавиш никуда не доставит событие
root.update()

# программно "нажимаем" клавишу, как это сделал бы пользователь
label.event_generate("<Key>", keysym="Up")
root.update()

print("Нажатия:", nazhatiya)
print("Текст метки:", label.cget("text"))
root.destroy()
# Out:
# Нажатия: ['Up']
# Текст метки: Вы нажали: Up

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Привяжите обработчик к событию `<Return>` (клавиша Enter) вместо `<Key>`.

# %%
root = tk.Tk()
label = tk.Label(root, text="Ожидание Enter")
label.pack()          # событие можно послать только отображённому виджету
root.update()
root.focus_force()   # без фокуса окна event_generate для клавиш никуда не доставит событие
root.update()

def na_enter(event):
    label.config(text="Enter нажат!")

root.bind("<Return>", na_enter)
label.event_generate("<Return>")
root.update()

print(label.cget("text"))
root.destroy()
# Out:
# Enter нажат!
