# %% [markdown]
# # 17-20 · Архитектура TicTacToeApp
#
# Практика к разделу [«Архитектура TicTacToeApp»](../../site/chapters/glava-17/17-20-arhitektura-app.html).

# %% [markdown]
# ## Цель
#
# Собрать минимальный объектный граф app.root / app.state и убедиться, что домен и UI разделены.

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# Вместо `root.mainloop()` здесь используется `root.update()` + `root.destroy()` — приложение строится точно так же, просто без бесконечного ожидания в конце (см. объяснение в ноутбуках главы 16).

# %% [markdown]
# ## Рабочий пример

# %%
import tkinter as tk
from dataclasses import dataclass, field

@dataclass
class GameState:
    board: list[str] = field(default_factory=lambda: [""] * 9)
    current_player: str = "X"

class TicTacToeApp:
    def __init__(self, root):
        self.root = root          # app HAS-A root — не наследование от tk.Tk
        self.state = GameState()  # app HAS-A state
        self.buttons = []

root = tk.Tk()
app = TicTacToeApp(root)
print("app.root — это Tk:", isinstance(app.root, tk.Tk))
print("app.state — это GameState:", isinstance(app.state, GameState))
root.update()
root.destroy()
# Out:
# app.root — это Tk: True
# app.state — это GameState: True

# %% [markdown]
# ## Задание ★★ Самостоятельная задача
#
# Добавьте методу build_board(self) создание девяти tk.Button и убедитесь, что len(self.buttons) == 9 после его вызова.

# %%
class TicTacToeApp:
    def __init__(self, root):
        self.root = root
        self.state = GameState()
        self.buttons = []

    def build_board(self):
        for index in range(9):
            btn = tk.Button(self.root, text="", width=3, height=1)
            btn.grid(row=index // 3, column=index % 3)
            self.buttons.append(btn)

root = tk.Tk()
app = TicTacToeApp(root)
app.build_board()
root.update()

print("Клеток в app.buttons:", len(app.buttons))
assert len(app.buttons) == 9

# Виджеты созданы — но модель по-прежнему пустая. Это и есть разделение:
# app.buttons — то, что видно; app.state — то, что игра на самом деле помнит.
assert app.state.board == [""] * 9
print("app.buttons — виджеты, app.state — состояние. Это разные вещи.")
root.destroy()
# Out:
# Клеток в app.buttons: 9
# app.buttons — виджеты, app.state — состояние. Это разные вещи.
