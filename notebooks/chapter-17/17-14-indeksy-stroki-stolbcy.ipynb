# %% [markdown]
# # 17-14 · Индексы, строки и столбцы
#
# Практика к разделу [«Индексы, строки и столбцы»](../../site/chapters/glava-17/17-14-indeksy-stroki-stolbcy.html).

# %% [markdown]
# ## Цель
#
# Преобразовать индекс клетки 0..8 в (row, column) и обратно.

# %% [markdown]
# ## Рабочий пример

# %%
def index_to_row_col(index):
    return index // 3, index % 3

def row_col_to_index(row, column):
    return row * 3 + column

for i in range(9):
    print(i, "->", index_to_row_col(i))
# Out:
# 0 -> (0, 0)
# 1 -> (0, 1)
# 2 -> (0, 2)
# 3 -> (1, 0)
# 4 -> (1, 1)
# 5 -> (1, 2)
# 6 -> (2, 0)
# 7 -> (2, 1)
# 8 -> (2, 2)

# %% [markdown]
# ## Задание ★ Базовая практика — round-trip для всех 9 клеток

# %%
roundtrip_ok = all(row_col_to_index(*index_to_row_col(i)) == i for i in range(9))
assert index_to_row_col(4) == (1, 1)
assert row_col_to_index(2, 2) == 8
assert roundtrip_ok is True
print("Прямое и обратное преобразование верны для всех 9 клеток.")
# Out:
# Прямое и обратное преобразование верны для всех 9 клеток.
