# %% [markdown]
# # 04-21 · statistics, inf и nan
#
# Практика к разделу [«statistics, inf и nan»](../../site/chapters/glava-04/04-21-statistics-i-inf-nan.html).

# %% [markdown]
# ## Цель
#
# Освоить statistics.mean/median и распознавание inf/nan.

# %% [markdown]
# ## Рабочий пример

# %%
import statistics
scores = [85, 90, 78, 92, 88]
print(statistics.mean(scores))
# Out:
# 86.6

# %% [markdown]
# ## Эксперимент 1
#
# Проверьте медиану того же списка.

# %%
import statistics
scores = [85, 90, 78, 92, 88]
print(statistics.median(scores))
# Out:
# 88

# %% [markdown]
# ## Эксперимент 2
#
# Проверьте странное свойство nan.

# %%
x = float("nan")
print(x == x)
# Out:
# False

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Проверьте float("inf") функцией math.isinf().

# %%
import math
y = float("inf")
print(math.isinf(y))
# Out:
# True
