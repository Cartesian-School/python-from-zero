# %% [markdown]
# # 04-19 · Модуль math
#
# Практика к разделу [«Модуль math»](../../site/chapters/glava-04/04-19-modul-math.html).

# %% [markdown]
# ## Цель
#
# Освоить основные группы функций модуля math.

# %% [markdown]
# ## Рабочий пример

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %% [markdown]
# ## Эксперимент 1
#
# Попробуйте целочисленную математику.

# %%
import math
print(math.factorial(5))
print(math.gcd(12, 18))
# Out:
# 120
# 6

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Посчитайте гипотенузу треугольника с катетами 6 и 8 через math.hypot().

# %%
import math
print(math.hypot(6, 8))
# Out:
# 10.0
