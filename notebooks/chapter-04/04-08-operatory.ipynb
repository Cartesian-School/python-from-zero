# %% [markdown]
# # 04-08 · Арифметические операторы
#
# Практика к разделу [«Арифметические операторы»](../../site/chapters/glava-04/04-08-operatory.html).

# %% [markdown]
# ## Цель
#
# Потренироваться в использовании полного набора арифметических операторов.

# %% [markdown]
# ## Рабочий пример

# %%
print(7 + 3)
print(7 - 3)
print(7 * 3)
print(7 / 3)
# Out:
# 10
# 4
# 21
# 2.3333333333333335

# %% [markdown]
# ## Эксперимент 1
#
# Предскажите результат каждой строки, прежде чем запускать.

# %%
print(7 // 3)
print(7 % 3)
print(7 ** 3)
# Out:
# 2
# 1
# 343

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Посчитайте цену со скидкой 15% от 1000, используя *, / и -.

# %%
price = 1000
discount_percent = 15
discount_amount = price * discount_percent / 100
final_price = price - discount_amount
print(final_price)
# Out:
# 850.0
