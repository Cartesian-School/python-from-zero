# %% [markdown]
# # 18-26 · Очистка холста
#
# Практика к разделу [«Очистка холста»](../../site/chapters/glava-18/18-26-ochistka-holsta.html).

# %% [markdown]
# ## Цель
#
# Очистка холста с подтверждением и полным обнулением истории.

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# Вместо `root.mainloop()` здесь используется `root.update()` + `root.destroy()` — приложение строится точно так же, просто без бесконечного ожидания в конце (см. объяснение в ноутбуках главы 16).

# %% [markdown]
# ## Рабочий пример

# %%
import tkinter as tk

root = tk.Tk()
canvas = tk.Canvas(root, width=300, height=200, bg="white")
canvas.pack()
canvas.create_rectangle(10, 10, 80, 60)
canvas.create_oval(100, 30, 160, 90)

document = ["rect", "oval"]
undo_stack = [["rect"], ["oval"]]

def clear_canvas():
    canvas.delete("all")
    document.clear()
    undo_stack.clear()

clear_canvas()
root.update()
print("Элементов на холсте:", len(canvas.find_all()), "| документ:", document, "| история:", undo_stack)
root.destroy()
# Out:
# Элементов на холсте: 0 | документ: [] | история: []

# %% [markdown]
# ## Задание ★★ Самостоятельная задача
#
# Добавьте `messagebox.askyesno(...)` перед очисткой — но только если `document` не пуст. Проверьте, что при пустом документе диалог не появляется вовсе.
