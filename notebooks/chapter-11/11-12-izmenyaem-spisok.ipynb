# %% [markdown]
# # 11-12 · Изменяем список
#
# Практика к разделу [«Изменяем список»](../../site/chapters/glava-11/11-12-izmenyaem-spisok.html).

# %% [markdown]
# ## Цель
#
# Изменить элемент списка по индексу.

# %% [markdown]
# ## Рабочий пример

# %%
numbers = [10, 20, 30]
numbers[1] = 999
print(numbers)
# Out:
# [10, 999, 30]

# %% [markdown]
# ## Задание ★ Базовая практика
#
# В списке температур на третий день (индекс 2) закралась ошибка измерения — должно быть 23, а не 19. Исправьте его на месте.

# %%
temperatures = [18, 21, 19, 25, 17]
temperatures[2] = 23
print(temperatures)
# Out:
# [18, 21, 23, 25, 17]
