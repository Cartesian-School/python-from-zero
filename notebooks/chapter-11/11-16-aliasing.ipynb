# %% [markdown]
# # 11-16 · Ссылки, aliasing, == и is
#
# Практика к разделу [«Ссылки, aliasing, == и is»](../../site/chapters/glava-11/11-16-ssylki-aliasing.html).

# %% [markdown]
# ## Цель
#
# Отличить aliasing от копирования, == от is.

# %% [markdown]
# ## Рабочий пример

# %%
a = [1, 2, 3]
b = a
b.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Дано `x = [10, 20]`. Создайте `y` как НАСТОЯЩУЮ копию x через `.copy()`, добавьте в y значение 30. Затем создайте `z = [10, 20, 30]` и сравните `z` с `y` через `==` и `is`.

# %%
x = [10, 20]
y = x.copy()
y.append(30)

z = [10, 20, 30]
ravny = (z == y)
odin_i_tot_zhe = (z is y)

print(x, y, ravny, odin_i_tot_zhe)
# Out:
# [10, 20] [10, 20, 30] True False
