# %% [markdown]
# # 11-23 · Как выбрать правильную структуру
#
# Практика к разделу [«Как выбрать правильную структуру»](../../site/chapters/glava-11/11-23-vybor-struktury.html).

# %% [markdown]
# ## Цель
#
# Выбрать подходящую коллекцию под сценарий.

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Для каждого сценария запишите название подходящего типа (`"list"`, `"tuple"`, `"set"` или `"dict"`) в соответствующую переменную:
#
# 1. `otvet_1` — хранение профиля пользователя: имя → email.
# 2. `otvet_2` — список уникальных ID посетителей, порядок не важен.
# 3. `otvet_3` — координата точки, которая не должна меняться.
# 4. `otvet_4` — список покупок, который будем пополнять и вычёркивать.

# %%
otvet_1 = "dict"
otvet_2 = "set"
otvet_3 = "tuple"
otvet_4 = "list"
print(otvet_1, otvet_2, otvet_3, otvet_4)
# Out:
# dict set tuple list
