# %% [markdown]
# # 19-03 · Голова и яблоко
#
# Практика к разделу [«Рисуем голову и яблоко»](../../site/chapters/glava-19/19-03-golova-yabloko.html).

# %% [markdown]
# ## Цель
#
# Создать голову и яблоко, разместить яблоко случайно.

# %% [markdown]
# ## Настройка (выполнить один раз)

# %%
import random
import turtle

RAZMER_SHAGA = 20
GRANICA = 280

screen = turtle.Screen()
screen.title("Змейка")
screen.bgcolor("black")
screen.setup(width=600, height=600)
screen.tracer(0)
print("Экран готов.")
# Out:
# Экран готов.

# %% [markdown]
# ## Рабочий пример

# %%
golova = turtle.Turtle()
golova.speed(0)
golova.shape("square")
golova.color("white")
golova.penup()
golova.goto(0, 0)

yabloko = turtle.Turtle()
yabloko.speed(0)
yabloko.shape("circle")
yabloko.color("red")
yabloko.penup()

def novoe_yabloko():
    x = random.randrange(-GRANICA, GRANICA, RAZMER_SHAGA)
    y = random.randrange(-GRANICA, GRANICA, RAZMER_SHAGA)
    yabloko.goto(x, y)

novoe_yabloko()
print("Голова:", golova.position())
print("Яблоко:", yabloko.position())
screen.update()
# Out:
# Голова: (0.00,0.00)
# Яблоко: (200.00,-280.00)

# %% [markdown]
# ## Эксперимент 1
#
# Проверьте, что яблоко всегда появляется «в клетке» (координаты кратны RAZMER_SHAGA).

# %%
for _ in range(5):
    novoe_yabloko()
    x, y = yabloko.position()
    print(x, y, "-> кратно шагу:", x % RAZMER_SHAGA == 0 and y % RAZMER_SHAGA == 0)
# Out:
# 100 -180 -> кратно шагу: True
# 140 -200 -> кратно шагу: True
# -80 -160 -> кратно шагу: True
# 40 -260 -> кратно шагу: True
# -140 -200 -> кратно шагу: True

# %% [markdown]
# ## Завершение (выполнить один раз, в самом конце)

# %%
screen.bye()
print("Окно закрыто.")
# Out:
# Окно закрыто.
