# %% [markdown]
# # 15-24 · Как выбрать формат хранения данных
#
# Практика к разделу [«Как выбрать формат хранения данных»](../../site/chapters/glava-15/15-24-kak-vybrat-format.html).

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Для каждой задачи выберите подходящий формат хранения: "текст", "CSV" или "JSON".

# %%
# настройки приложения (вложенная структура: тема, язык, размер окна)
vybor_dlya_nastroek = "JSON"

# таблица результатов игроков (одинаковые строки: имя, очки, уровень)
vybor_dlya_tablitsy_rezultatov = "CSV"

# простой список заметок, одна на строку
vybor_dlya_zametok = "текст"

print(vybor_dlya_nastroek, vybor_dlya_tablitsy_rezultatov, vybor_dlya_zametok)
# Out:
# JSON CSV текст
