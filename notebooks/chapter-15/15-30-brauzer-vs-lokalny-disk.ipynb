# %% [markdown]
# # 15-30 · Браузер и локальный диск: две файловые системы
#
# Локальная практика к разделу [«Браузер и локальный диск»](../../site/chapters/glava-15/15-30-brauzer-vs-lokalny-disk.html).
#
# **Этот ноутбук выполняется локально** — смысл упражнения именно в том, чтобы увидеть настоящую персистентность на настоящем диске, а не в виртуальной файловой системе браузера.

# %% [markdown]
# ## Шаг 1 — создаём файл в реальной папке data/

# %%
from pathlib import Path

Path("data").mkdir(exist_ok=True)
Path("data/moya_zametka.txt").write_text("Привет с настоящего диска!", encoding="utf-8")
print("Файл записан в data/moya_zametka.txt")
# Out:
# Файл записан в data/moya_zametka.txt

# %% [markdown]
# ## Шаг 2 — остановите выполнение, затем запустите ноутбук заново

# %%
from pathlib import Path

print(Path("data/moya_zametka.txt").read_text(encoding="utf-8"))
# Out:
# Привет с настоящего диска!

# %% [markdown]
# ## Задание ★★ Самостоятельная задача
#
# Откройте `data/moya_zametka.txt` в проводнике/Finder или в самом редакторе — убедитесь, что это настоящий файл на вашем диске, а не что-то видимое только внутри этого ноутбука.
