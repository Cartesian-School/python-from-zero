# %% [markdown]
# # 20-18 · Rect и система координат
#
# Практика к разделу [«Rect и система координат»](../../site/chapters/glava-20/20-18-rect-i-koordinaty.html). Здесь Rect воспроизведён обычным кортежем (x, y, ширина, высота) — идея та же, настоящее окно не требуется.

# %% [markdown]
# ## Цель
#
# Считать границы прямоугольника вручную и подтвердить, что ось Y в Pygame растёт вниз.

# %% [markdown]
# ## Рабочий пример

# %%
def granicy(rect):
    x, y, w, h = rect
    return {"left": x, "top": y, "right": x + w, "bottom": y + h, "center": (x + w / 2, y + h / 2)}

igrok = (100, 200, 40, 40)
g = granicy(igrok)
print(g)

# "Прыжок вверх" на экране Pygame — это УМЕНЬШЕНИЕ y, а не увеличение
y_do_pryzhka = 300
y_posle_pryzhka = y_do_pryzhka - 50   # выше на экране = меньшее y
print("До прыжка y =", y_do_pryzhka, " после прыжка y =", y_posle_pryzhka)
# Out:
# {'left': 100, 'top': 200, 'right': 140, 'bottom': 240, 'center': (120.0, 220.0)}
# До прыжка y = 300  после прыжка y = 250

# %% [markdown]
# ## Проверка результата

# %%
assert g["right"] == 140
assert g["bottom"] == 240
assert g["center"] == (120.0, 220.0)
assert y_posle_pryzhka < y_do_pryzhka
print("Верно: границы посчитаны правильно, и прыжок вверх уменьшает y, как и на экране Pygame.")
# Out:
# Верно: границы посчитаны правильно, и прыжок вверх уменьшает y, как и на экране Pygame.
