# %% [markdown]
# # 16-03 · Поля ввода
#
# Практика к разделу [«Множество полей ввода»](../../site/chapters/glava-16/16-03-polya-vvoda.html).

# %% [markdown]
# ## Цель
#
# Освоить Entry и Text.

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# В обычном `.py`-файле приложение запускают через `root.mainloop()` — эта команда «замирает» и ждёт, пока пользователь не закроет окно. В автоматически выполняемом ноутбуке нет живого пользователя за окном, поэтому здесь вместо `root.mainloop()` мы вызовем `root.update()` (обрабатывает события один раз, без ожидания) и затем `root.destroy()` — интерфейс строится точно так же, просто без бесконечного ожидания в конце.

# %% [markdown]
# ## Рабочий пример — Entry

# %%
import tkinter as tk

root = tk.Tk()

entry = tk.Entry(root)
entry.pack()
entry.insert(0, "Cartesian")   # программно вводим текст, как это сделал бы пользователь

print("Текст в поле:", entry.get())
root.update()
root.destroy()
# Out:
# Текст в поле: Cartesian

# %% [markdown]
# ## Эксперимент 1 — Text (многострочный)

# %%
root = tk.Tk()

text_box = tk.Text(root, height=5, width=30)
text_box.pack()
text_box.insert("1.0", "Первая строка\nВторая строка")

content = text_box.get("1.0", "end")
print(repr(content))
root.update()
root.destroy()
# Out:
# 'Первая строка\nВторая строка\n'

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Создайте Entry, вставьте своё имя и выведите его заглавными буквами (используя upper() из главы 8).

# %%
root = tk.Tk()
entry = tk.Entry(root)
entry.pack()
entry.insert(0, "cartesian")

print(entry.get().upper())
root.update()
root.destroy()
# Out:
# CARTESIAN
