# %% [markdown]
# # 16-13 · Frame и LabelFrame
#
# Практика к разделу [«Frame и LabelFrame»](../../site/chapters/glava-16/16-13-frame-i-labelframe.html).

# %% [markdown]
# ## Цель
#
# Разбить окно на регионы через Frame.

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# В обычном `.py`-файле приложение запускают через `root.mainloop()` — эта команда «замирает» и ждёт, пока пользователь не закроет окно. В автоматически выполняемом ноутбуке нет живого пользователя за окном, поэтому здесь вместо `root.mainloop()` мы вызовем `root.update()` (обрабатывает события один раз, без ожидания) и затем `root.destroy()` — интерфейс строится точно так же, просто без бесконечного ожидания в конце.

# %%
import tkinter as tk
from tkinter import ttk

root = tk.Tk()

toolbar_frame = ttk.Frame(root)
content_frame = ttk.Frame(root)
status_frame = ttk.Frame(root)

toolbar_frame.pack(side="top", fill="x")
content_frame.pack(side="top", fill="both", expand=True)
status_frame.pack(side="bottom", fill="x")

root.update()
print(len(root.winfo_children()), "региона в root")
root.destroy()
# Out:
# 3 региона в root

# %% [markdown]
# ## Задание ★ Базовая практика — LabelFrame

# %%
root = tk.Tk()
nastrojki = ttk.LabelFrame(root, text="Настройки")
nastrojki.pack(padx=10, pady=10, fill="x")
ttk.Checkbutton(nastrojki, text="Тёмная тема").pack(anchor="w")
root.update()
print(nastrojki.cget("text"))
root.destroy()
# Out:
# Настройки
