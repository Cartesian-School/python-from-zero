# %% [markdown]
# # 16-09 · От терминала к GUI
#
# Практика к разделу [«От терминала к GUI: событийная модель»](../../site/chapters/glava-16/16-09-ot-terminala-k-gui.html).

# %% [markdown]
# ## Цель
#
# Понять разницу между регистрацией callback и его выполнением.

# %%
log = []

def on_click():
    log.append("clicked")

registered = on_click            # регистрация: callback запомнен, но НЕ вызван
before_dispatch = list(log)

registered()                     # диспетчеризация: callback выполняется именно сейчас
after_dispatch = list(log)

print(before_dispatch, after_dispatch)
# Out:
# [] ['clicked']

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Проверьте, что registered — это вызываемый объект (функция), а не результат её вызова.

# %%
registered_is_callable = callable(registered)
print(registered_is_callable)
# Out:
# True
