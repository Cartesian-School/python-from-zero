# %% [markdown]
# # 16-04 · Переменные Tkinter
#
# Практика к разделу [«Переменные Tkinter»](../../site/chapters/glava-16/16-04-peremennye-tkinter.html).

# %% [markdown]
# ## Цель
#
# Освоить StringVar и обновление связанных виджетов.

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# В обычном `.py`-файле приложение запускают через `root.mainloop()` — эта команда «замирает» и ждёт, пока пользователь не закроет окно. В автоматически выполняемом ноутбуке нет живого пользователя за окном, поэтому здесь вместо `root.mainloop()` мы вызовем `root.update()` (обрабатывает события один раз, без ожидания) и затем `root.destroy()` — интерфейс строится точно так же, просто без бесконечного ожидания в конце.

# %% [markdown]
# ## Рабочий пример

# %%
import tkinter as tk

root = tk.Tk()
imya = tk.StringVar(value="Гость")

label = tk.Label(root, textvariable=imya)
label.pack()

print("До смены:", label.cget("text"))

imya.set("Cartesian")
root.update()   # применяем изменение к виджету

print("После смены:", label.cget("text"))
root.destroy()
# Out:
# До смены: Гость
# После смены: Cartesian

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Создайте IntVar со счётчиком, который увеличивается при вызове функции.

# %%
root = tk.Tk()
schet = tk.IntVar(value=0)
label = tk.Label(root, textvariable=schet)
label.pack()

def uvelichit():
    schet.set(schet.get() + 1)

uvelichit()
uvelichit()
uvelichit()
root.update()
print("Значение счётчика:", schet.get())
root.destroy()
# Out:
# Значение счётчика: 3
