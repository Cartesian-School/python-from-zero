# %% [markdown]
# # 16-01 · Настройка Tkinter
#
# Практика к разделу [«Tkinter — правильно всё настраиваем!»](../../site/chapters/glava-16/16-01-nastraivaem-tkinter.html).

# %% [markdown]
# ## Цель
#
# Создать первое окно Tkinter.

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# В обычном `.py`-файле приложение запускают через `root.mainloop()` — эта команда «замирает» и ждёт, пока пользователь не закроет окно. В автоматически выполняемом ноутбуке нет живого пользователя за окном, поэтому здесь вместо `root.mainloop()` мы вызовем `root.update()` (обрабатывает события один раз, без ожидания) и затем `root.destroy()` — интерфейс строится точно так же, просто без бесконечного ожидания в конце.

# %% [markdown]
# ## Рабочий пример

# %%
import tkinter as tk

root = tk.Tk()
root.title("Моё первое приложение")
root.geometry("400x300")

print("Заголовок окна:", root.title())
root.update()
root.destroy()
print("Окно закрыто.")
# Out:
# Заголовок окна: Моё первое приложение
# Окно закрыто.

# %% [markdown]
# ## Задание ★ Базовая практика
#
# Создайте окно 300x200 со своим заголовком.

# %%
root = tk.Tk()
root.title("Окно Cartesian")
root.geometry("300x200")

print(root.title(), root.geometry())
root.update()
root.destroy()
# Out:
# Окно Cartesian 1x1+0+0
