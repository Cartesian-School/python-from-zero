# %% [markdown]
# # 16-20 · Toplevel
#
# Практика к разделу [«Toplevel: несколько окон»](../../site/chapters/glava-16/16-20-toplevel.html).

# %% [markdown]
# ## Цель
#
# Открыть дополнительное окно через Toplevel, а не второй Tk().

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# В обычном `.py`-файле приложение запускают через `root.mainloop()` — эта команда «замирает» и ждёт, пока пользователь не закроет окно. В автоматически выполняемом ноутбуке нет живого пользователя за окном, поэтому здесь вместо `root.mainloop()` мы вызовем `root.update()` (обрабатывает события один раз, без ожидания) и затем `root.destroy()` — интерфейс строится точно так же, просто без бесконечного ожидания в конце.

# %%
import tkinter as tk
from tkinter import ttk

root = tk.Tk()

def otkryt_nastrojki():
    okno_nastrojek = tk.Toplevel(root)
    okno_nastrojek.title("Настройки")
    ttk.Label(okno_nastrojek, text="Здесь будут настройки").pack(padx=20, pady=20)
    return okno_nastrojek

okno = otkryt_nastrojki()
root.update()
print(type(okno).__name__, okno.title())
okno.destroy()
root.destroy()
# Out:
# Toplevel Настройки
