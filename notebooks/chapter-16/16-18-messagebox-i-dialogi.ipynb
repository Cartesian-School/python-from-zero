# %% [markdown]
# # 16-18 · Messagebox и диалоги
#
# Практика к разделу [«Messagebox и диалоги»](../../site/chapters/glava-16/16-18-messagebox-i-dialogi.html).

# %% [markdown]
# ## Цель
#
# Показать диалог и корректно обработать возвращённое значение.

# %% [markdown]
# ## Про mainloop() в этом ноутбуке
#
# В обычном `.py`-файле приложение запускают через `root.mainloop()` — эта команда «замирает» и ждёт, пока пользователь не закроет окно. В автоматически выполняемом ноутбуке нет живого пользователя за окном, поэтому здесь вместо `root.mainloop()` мы вызовем `root.update()` (обрабатывает события один раз, без ожидания) и затем `root.destroy()` — интерфейс строится точно так же, просто без бесконечного ожидания в конце.

# %% [markdown]
# ## Про messagebox в этом ноутбуке
#
# Модальные диалоги ждут реального нажатия кнопки живым пользователем. В автоматически выполняемом ноутбуке никто не нажмёт кнопку, поэтому нужные функции `messagebox` временно подменены заранее заготовленными ответами.

# %%
from tkinter import messagebox

messagebox.askyesno = lambda *args, **kwargs: True
messagebox.showinfo = lambda *args, **kwargs: None

# %%
import tkinter as tk

root = tk.Tk()
otvet = messagebox.askyesno("Выход", "Сохранить изменения перед выходом?")
if otvet:
    messagebox.showinfo("Готово", "Изменения сохранены.")
print("Ответ пользователя:", otvet)
root.destroy()
# Out:
# Ответ пользователя: True
