# %% [markdown]
# # 12-17 · Викторина — процент правильных ответов
#
# Практика к разделу [«Проект: викторина»](../../site/chapters/glava-12/12-16-viktorina.html#uroven-4).

# %% [markdown]
# ## Цель
#
# Уровень 4: посчитать долю правильных ответов в процентах.

# %% [markdown]
# ## Про input() в этом ноутбуке
#
# Этот ноутбук выполняется автоматически, поэтому `input()` временно подменён на заранее заготовленные ответы.

# %%
_answers = iter(['paris', '54', 'python'])

def input(prompt=""):
    answer = next(_answers)
    print(prompt + answer)
    return answer

# %% [markdown]
# ## Задание ★★★★ Challenge

# %%
questions = [
    {"question": "Столица Франции?", "answer": "paris"},
    {"question": "7 * 8?", "answer": "56"},
    {"question": "Язык, который мы изучаем?", "answer": "python"},
]

score = 0
for q in questions:
    user_answer = input(q["question"] + " ").strip().lower()
    if user_answer == q["answer"]:
        score += 1

procent = score / len(questions) * 100
print(f"Результат: {procent:.0f}%")
# Out:
# Столица Франции? paris
# 7 * 8? 54
# Язык, который мы изучаем? python
# Результат: 67%
