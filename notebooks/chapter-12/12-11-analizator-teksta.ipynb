# %% [markdown]
# # 12-11 · Анализатор текста
#
# Практика к разделу [«Проект: анализатор текста и частота слов»](../../site/chapters/glava-12/12-11-analizator-teksta.html).

# %% [markdown]
# ## Цель
#
# Символы, слова, уникальные слова — строки, циклы и множества вместе.

# %% [markdown]
# ## Про input() в этом ноутбуке
#
# Этот ноутбук выполняется автоматически, поэтому `input()` временно подменён на заранее заготовленные ответы.

# %%
_answers = iter(['Python is great and python is fun'])

def input(prompt=""):
    answer = next(_answers)
    print(prompt + answer)
    return answer

# %% [markdown]
# ## Рабочий пример

# %%
text = input("Введите текст: ")
normalized = text.lower().split()
unikalnye = set(normalized)

kolichestvo_simvolov = len(text)
kolichestvo_slov = len(normalized)
kolichestvo_unikalnyh = len(unikalnye)

print("Символов:", kolichestvo_simvolov)
print("Слов:", kolichestvo_slov)
print("Уникальных слов:", kolichestvo_unikalnyh)
# Out:
# Введите текст: Python is great and python is fun
# Символов: 33
# Слов: 7
# Уникальных слов: 5
